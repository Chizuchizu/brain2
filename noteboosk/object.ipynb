# %%
import pandas as pd

# %%
data = pd.read_pickle("../features/finger_print.pkl")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6311 entries, 0 to 6310
# Columns: 2048 entries, 0 to 2047
# dtypes: int64(2048)
# memory usage: 98.6 MB

# %%
df = pd.read_pickle("../features/mordred_fe.pkl")

# %%
df
# Out:
#             ABC      ABCGG  nAcid  nBase                             SpAbs_A  \
# 0     12.158715  10.010893      0      0                             19.4978
# 1      9.968445   8.418999      1      1  multiple fragments (SpAbs_A/SpAbs)
# 2      3.535534   3.535534      0      1                             6.47214
# 3     11.560998  10.010108      0      0                             19.0483
# 4     12.785300  11.747745      0      0                             19.2798
# ...         ...        ...    ...    ...                                 ...
# 6306   9.826314   9.493560      0      0                             14.5629
# 6307   7.289847   6.783462      0      1                             12.0668
# 6308  15.015651  13.091997      0      1                             25.2305
# 6309   5.875634   5.525875      0      0                             9.92478
# 6310  13.722758  11.378360      0      1                              23.141
#
#                                  SpMax_A  \
# ...

# %%
df.info()
# Out:
# <class 'mordred._base.pandas_module.MordredDataFrame'>
# RangeIndex: 6311 entries, 0 to 6310
# Columns: 1613 entries, ABC to mZagreb2
# dtypes: bool(2), float64(381), int64(300), object(930)
# memory usage: 77.6+ MB

# %%
import numpy as np
pd.to_numeric(df["SpAbs_A"], errors="coerce")
# Out:
# 0       19.497784
# 1             NaN
# 2        6.472136
# 3       19.048316
# 4       19.279792
#           ...
# 6306    14.562939
# 6307    12.066822
# 6308    25.230531
# 6309     9.924777
# 6310    23.141010
# Name: SpAbs_A, Length: 6311, dtype: float64

# %%
df["SpAbs_A"].astype
# Out:
# <bound method NDFrame.astype of 0                                  19.4978
# 1       multiple fragments (SpAbs_A/SpAbs)
# 2                                  6.47214
# 3                                  19.0483
# 4                                  19.2798
#                        ...
# 6306                               14.5629
# 6307                               12.0668
# 6308                               25.2305
# 6309                               9.92478
# 6310                                23.141
# Name: SpAbs_A, Length: 6311, dtype: object>
